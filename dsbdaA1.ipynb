# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("hi.csv")

# %%
df.head()
# Out:
#    Kindly Rate your Sleep Quality 😴  \
# 0                                 3
# 1                                 4
# 2                                 2
# 3                                 3
# 4                                 2
#
#    How many times a week do you suffer headaches 🤕?  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 2
# 4                                                 3
#
#    How would you rate you academic performance 👩‍🎓?  \
# 0                                                 3
# 1                                                 2
# 2                                                 2
# 3                                                 3
# 4                                                 1
#
#    how would you rate your study load?  \
# 0                                    4
# ...

# %%
df.tail()
# Out:
#      Kindly Rate your Sleep Quality 😴  \
# 515                                 3
# 516                                 2
# 517                                 2
# 518                                 3
# 519                                 5
#
#      How many times a week do you suffer headaches 🤕?  \
# 515                                                 2
# 516                                                 4
# 517                                                 3
# 518                                                 4
# 519                                                 1
#
#      How would you rate you academic performance 👩‍🎓?  \
# 515                                                 4
# 516                                                 3
# 517                                                 5
# 518                                                 3
# 519                                                 5
#
#      how would you rate your study load?  \
# ...

# %%
df.describe()
# Out:
#        Kindly Rate your Sleep Quality 😴  \
# count                        520.000000
# mean                           3.125000
# std                            1.099023
# min                            1.000000
# 25%                            2.000000
# 50%                            3.000000
# 75%                            4.000000
# max                            5.000000
#
#        How many times a week do you suffer headaches 🤕?  \
# count                                        520.000000
# mean                                           2.182692
# std                                            1.247459
# min                                            1.000000
# 25%                                            1.000000
# 50%                                            2.000000
# 75%                                            3.000000
# max                                            5.000000
#
#        How would you rate you academic performance 👩‍🎓?  \
# ...

# %%
df1=df.hist()
# Out:
# /home/comp577/conda/envs/a1sid/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 129301 (\N{FACE WITH HEAD-BANDAGE}) missing from current font.
#   func(*args, **kwargs)
# /home/comp577/conda/envs/a1sid/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 128105 (\N{WOMAN}) missing from current font.
#   func(*args, **kwargs)
# /home/comp577/conda/envs/a1sid/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 127891 (\N{GRADUATION CAP}) missing from current font.
#   func(*args, **kwargs)
# /home/comp577/conda/envs/a1sid/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 127934 (\N{TENNIS RACQUET AND BALL}) missing from current font.
#   func(*args, **kwargs)
# /home/comp577/conda/envs/a1sid/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 129301 (\N{FACE WITH HEAD-BANDAGE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df.isnull()
# Out:
#      Kindly Rate your Sleep Quality 😴  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# ..                                ...
# 515                             False
# 516                             False
# 517                             False
# 518                             False
# 519                             False
#
#      How many times a week do you suffer headaches 🤕?  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ..                                                ...
# 515                                             False
# 516                                             False
# ...

# %%
df2=df.loc[:,["Kindly Rate your Sleep Quality 😴","How would you rate you academic performance 👩‍🎓?"]]

# %%
df2
# Out:
#      Kindly Rate your Sleep Quality 😴  \
# 0                                   3
# 1                                   4
# 2                                   2
# 3                                   3
# 4                                   2
# ..                                ...
# 515                                 3
# 516                                 2
# 517                                 2
# 518                                 3
# 519                                 5
#
#      How would you rate you academic performance 👩‍🎓?
# 0                                                   3
# 1                                                   2
# 2                                                   2
# 3                                                   3
# 4                                                   1
# ..                                                ...
# 515                                                 4
# 516                                                 3
# ...

# %%
df2.hist()
# Out:
# array([[<Axes: title={'center': 'Kindly Rate your Sleep Quality 😴'}>,
#         <Axes: title={'center': 'How would you rate you academic performance 👩\u200d🎓?'}>]],
#       dtype=object)
# /home/comp577/conda/envs/a1sid/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 128105 (\N{WOMAN}) missing from current font.
#   func(*args, **kwargs)
# /home/comp577/conda/envs/a1sid/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 127891 (\N{GRADUATION CAP}) missing from current font.
#   func(*args, **kwargs)
# /home/comp577/conda/envs/a1sid/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128105 (\N{WOMAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/comp577/conda/envs/a1sid/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127891 (\N{GRADUATION CAP}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df2.sum()
# Out:
# Kindly Rate your Sleep Quality 😴                    1625
# How would you rate you academic performance 👩‍🎓?    1730
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Kindly Rate your Sleep Quality 😴                    0
# How would you rate you academic performance 👩‍🎓?    0
# dtype: int64

# %%
df2
# Out:
#      Kindly Rate your Sleep Quality 😴  \
# 0                                   3
# 1                                   4
# 2                                   2
# 3                                   3
# 4                                   2
# ..                                ...
# 515                                 3
# 516                                 2
# 517                                 2
# 518                                 3
# 519                                 5
#
#      How would you rate you academic performance 👩‍🎓?
# 0                                                   3
# 1                                                   2
# 2                                                   2
# 3                                                   3
# 4                                                   1
# ..                                                ...
# 515                                                 4
# 516                                                 3
# ...

# %%
pd.index(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 pd.index(2)
#
# AttributeError: module 'pandas' has no attribute 'index'
